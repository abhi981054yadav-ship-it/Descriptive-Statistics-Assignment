# %% [markdown]
#   #                                    Descriptive Statistics  Assignment

# %% [markdown]
# Q1: Understanding Central Tendency (Easy)
#
# A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?

# %% [markdown]
# -> First, we add all the values:
# 10 + 12 + 11 + 15 + 14 + 13 + 12 = 87
#
# Then divide by 7:
# 87 ÷ 7 = 12.43

# %% [markdown]
# Q2: Mean in Real Life (Easy)
#
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?

# %% [markdown]
# -> Marks: 12, 15, 14, 16, 18, 20, 19
#
#    MEAN: Sum of all observation/ Number of observation
#
# First, add all the marks:
# 12 + 15 + 14 + 16 + 18 + 20 + 19 = 114
#
# Now divide by 7:
# 114 ÷ 7 = 16.29.
#
# It tell us about the class's performance that the average performance of the class is around 16 marks out of the total, which means the students did fairly well overall in the quiz.

# %% [markdown]
# Q3: Mode in Real Life (Easy)
#
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?

# %% [markdown]
# -> Data: 7, 8, 9, 8, 8, 10, 7, 9
#
#  Mode = 8
#
# Because 8 comes the most times (3 times) compared to other numbers.
#
# It is useful for the store manager because it shows that size 8 is the most sold shoe size, so the manager should keep more stock of size 8.

# %% [markdown]
# Q4: Median in Real Life (Medium)
#
# A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median.

# %% [markdown]
# -> Data:  8,000, 9,500, 10,200, 11,000, 50,000
#
#  Median = $10,200
#
# Because it is the middle number when data is arranged in order.
#
# Median is better here because $50,000 is very big value, it is an outlier.
# It affects the mean, so mean will not be correct.
#
# So median gives the correct middle idea of prices.

# %% [markdown]
# Q5: Dispersion Introduction (Medium)
#
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time?

# %% [markdown]
# -> Data: 25, 30, 27, 35, 40
#
#  Range = 15
#
# (because 40 − 25 = 15)
#
# Range shows the difference between highest and lowest time.
# So it tells that the student’s puzzle time is changing by 15 minutes, not same every day.

# %% [markdown]
# Q6: Range in Action (Medium)
#
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his  packaging?

# %% [markdown]
# Data: 100, 105, 98, 110, 120
#
# Range:Highest = 120,
# Lowest = 98
#
# Range = 120 − 98 = 22
# Range = 22 kg
#
# It shows the weight is changing by 22 kg.
# So the farmer can know how much apples can increase or decrease and he can plan packaging boxes according to this variation.

# %% [markdown]
# Q7: Variance for Decision-Making (Medium)
#
# Two delivery companies track delivery delays (in minutes).
#
# * Company A: variance = 6
#
# * Company B: variance = 15
#  Which company is more consistent, and why?

# %% [markdown]
# Company A is more consistent.
#
# Because its variance is 6, which is smaller than 15 of Company B.
# Lower variance means less change, so Company A is more stable.

# %% [markdown]
# Q8: Standard Deviation in Context (Hard)
#
# A finance student compares the daily price fluctuations of two cryptocurrencies.
#
# * Coin A: standard deviation = $30
#
# * Coin B: standard deviation = $120
#  Which coin is riskier to invest in, and why?

# %% [markdown]
# -> Coin B is more riskier because its standard deviation is bigger $ 120 .   This means its prices go up and down more compared to Coin A $ 30, so it is less stable. Because of more fluctuation, there is higher chance of loss, so it is more risky to invest in Coin B.

# %% [markdown]
# Q9: Combining Measures (Hard)
#
# A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
#
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?

# %% [markdown]
# -> Mean = (400 + 420 + 390 + 450 + 410) / 5
#
# = 2070 / 5
# = 414
#
# Standard deviation formula:
# σ = √[ Σ (x − μ)² / N ]  this formula copy from google for reffrence
#
#
#
#
# Deviations:
# 400 − 414 = −14
#
# 420 − 414 = 6
#
# 390 − 414 = −24
#
# 450 − 414 = 36
#
# 410 − 414 = −4
#
#
# Squares:
# 196, 36, 576, 1296, 16
#
# Sum = 2120
#
# Variance = 2120 / 5 = 424
#
# = √424 ≈ 20.6
#
# Conclusion:
#
# Mean is 414 so family uses around 414 electricity. Standard deviation is 20.6 so not very big. So values are near mean only. So usage is almost same every month, just little bit change sometimes.

# %% [markdown]
# Q10: Practical Application (Hard)
#
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
#
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance?

# %% [markdown]
# -> Mean = (15 + 18 + 20 + 22 + 25 + 17 + 19 + 21) / 8
#
# = 157 / 8
# = 19.6
#
# Arrange data:
# 15, 17, 18, 19, 20, 21, 22, 25
#
# Median = (19 + 20) / 2 = 19.5
#
# Mode = no repeating value, so no mode
#
# Range = 25 − 15 = 10
#
# Standard deviation formula:
# σ = √[ Σ (x − μ)² / N ]
# Take μ = 19.6
#
# Deviations :
# −4.6, −1.6, 0.4, 2.4, 5.4, −2.6, −0.6, 1.4
#
# Squares:
# 21.16, 2.56, 0.16, 5.76, 29.16, 6.76, 0.36, 1.96
#
# Sum ≈ 67.92
#
# Variance ≈ 67.92 / 8 = 8.49
#
#  = √8.49 = 2.9
#
# Conclusion :
# Mean is about 19.6 so player scores near 20 points. Median also close so data is normal. No mode because all different. Range is 10 so not very big difference. Standard deviation is small (2.9) so values are near mean. So player is playing almost same in every game and performance is quite consistent.

# %% [markdown]
# If you want any calculation then let me so i can add rough calculation photos with assignment. Thankyou
